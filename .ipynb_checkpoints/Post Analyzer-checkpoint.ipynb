# %% [markdown]
# <img src="http://andtek.pro/wp-content/uploads/2016/12/Sonity-FINAL-350x350.jpg" width="240" height="240" align="center"/>
#
# # SonityWolf Post Analyzer
#
# ## Microtargeting tool
#
# Based on the information provided by the profilecrawl, this notebook generates hashtags microtargeting the users based on the analysis of your profile

# %%
#dependences:
from os import listdir
from os.path import isfile, join
import json
from pprint import pprint
from collections import Counter

# %%
accounts = [f.replace(".json","") for f in listdir("./accounts") if isfile(join("./accounts", f))]
print("Accounts Avalaible:")
for index, account in enumerate(accounts):
    print(f"{index} - {account}")
# Out:
# Accounts Avalaible:
# 0 - andtek.pro
# 1 - patrick_maciazek

# %%
account = accounts[0] #Choose one of the list starting from 0

# %%
account
# Out:
# 'andtek.pro'

# %%
with open(f"accounts/{account}.json") as f:
    data = json.load(f)
pprint(data)
# Out:
# {'alias': 'Ian Andtek',
#  'bio': '🚀 Serial entrepreneur (12 software companies) @elonmusk you are '
#         'targeted. 🎥 2D/3D Animator 🎹 Professional musician 💻 High Skilled '
#         'developer. 1997 🇨🇦',
#  'followers': 4671,
#  'following': 1728,
#  'num_of_posts': 341,
#  'posts': [{'caption': 'Friday!!! #friday #funtime #Friends #cool #love',
#             'comments': 0,
#             'date': '2017-02-18T01:49:59.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/eda31a26b665656676ffe27ab942d7a6/5BB3F7AD/t51.2885-15/e35/16583795_946641518805609_836221035790467072_n.jpg',
#             'likes': 36,
#             'location': {'latitude': 43.6678265344,
#                          'location_id': '312110943',
#                          'location_name': 'The Madison',
#                          'location_url': 'https://www.instagram.com/explore/locations/312110943/the-madison/',
#                          'longitude': -79.4034477961},
#             'tags': ['#friday', '#funtime', '#Friends', '#cool', '#love']},
#            {'caption': 'Presentación de ayer!!! #GrupoASA #FILA2015 #cool '
#                        '#music #keyboards @fundapromusik @festival_fila '
#                        '#teatro #teatrocomprimido #me #cool #computer '
#                        '#rockprog',
#             'comments': 3,
#             'date': '2015-06-13T16:28:04.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/d986048e8d9b6261cceedf25269c7700/5BC52555/t51.2885-15/e15/11330766_1604714686434644_1168425121_n.jpg',
#             'likes': 28,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#GrupoASA',
#                      '#FILA2015',
#                      '#cool',
#                      '#music',
#                      '#keyboards',
#                      '#teatro',
#                      '#teatrocomprimido',
#                      '#me',
#                      '#cool',
#                      '#computer',
#                      '#rockprog',
#                      '#mac',
#                      '#apple',
#                      '#server',
#                      '#programming',
#                      '#scifi']},
#            {'caption': 'Inside Lamborghini Gallardo! #car #lamborghini #cool '
#                        '#interior #luxury #toronto #canada',
#             'comments': 8,
#             'date': '2017-02-22T02:58:33.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/a0b914f9d2118494efa736a612d25411/5BC1701E/t51.2885-15/e35/16585163_1335796749828244_3604951130263519232_n.jpg',
#             'likes': 27,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#car',
#                      '#lamborghini',
#                      '#cool',
#                      '#interior',
#                      '#luxury',
#                      '#toronto',
#                      '#canada']},
#            {'caption': 'Y esto es lo que pasa cuando hackeas candy crush '
#                        '#CandyCrush #Fail #Hack #game #Videogames',
#             'comments': 2,
#             'date': '2013-11-05T21:57:23.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/1fc8f5945d111f409b6dfae9ef80f743/5BB1AD9C/t51.2885-15/e15/1208424_174779806059213_67503068_n.jpg',
#             'likes': 5,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#CandyCrush', '#Fail', '#Hack', '#game', '#Videogames']},
#            {'caption': 'Mustang GT 2017 #mustang #car #ford #interior',
#             'comments': 2,
#             'date': '2017-02-24T16:05:08.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/1abb4ffa1e7440a0ca141b72ac9e66be/5BBF05AC/t51.2885-15/e35/16906119_257637311348318_400055244181995520_n.jpg',
#             'likes': 17,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#mustang', '#car', '#ford', '#interior']},
#            {'caption': 'Una de las mejores experiencias que he tenido en mi '
#                        'vida :) #GrupoASA @andreaaigliozzi',
#             'comments': 0,
#             'date': '2015-06-13T16:33:32.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/aa1ad0b54b8c0548cbcd1266092889cd/5BA49E80/t51.2885-15/e15/11333548_1672532219647724_427925542_n.jpg',
#             'likes': 15,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#GrupoASA']},
#            {'caption': 'With te brous!',
#             'comments': 2,
#             'date': '2016-12-30T00:31:26.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/1bbdac48710976d049e9e4359f64a0ec/5BB0483A/t51.2885-15/e35/15802956_978803922251906_6533157994706763776_n.jpg',
#             'likes': 197,
#             'location': {'latitude': 10.4924393769,
#                          'location_id': '214790531',
#                          'location_name': 'Gran Meliá Caracas',
#                          'location_url': 'https://www.instagram.com/explore/locations/214790531/gran-melia-caracas/',
#                          'longitude': -66.8778541999},
#             'tags': []},
#            {'caption': '#homeserver #hp #proliant #caracas #venezuela '
#                        '#1TBofRAM #NVIDIA #Custom #Graphics',
#             'comments': 6,
#             'date': '2016-12-03T16:25:16.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/ffdc390998beacc2d85e207ebcc6771f/5BA33986/t51.2885-15/e35/15258773_1338848956125732_7318631054137360384_n.jpg',
#             'likes': 219,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#homeserver',
#                      '#hp',
#                      '#proliant',
#                      '#caracas',
#                      '#venezuela',
#                      '#1TBofRAM',
#                      '#NVIDIA',
#                      '#Custom',
#                      '#Graphics',
#                      '#CallOrText']},
#            {'caption': 'Lambo! #car #lamborghini #toronto #canada',
#             'comments': 1,
#             'date': '2017-02-22T00:37:00.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/cd3d148796da73e0d3e9c6a664ef8562/5BAC2297/t51.2885-15/e35/16465521_720604424775960_7738830021355110400_n.jpg',
#             'likes': 32,
#             'location': {'latitude': 43.6426238702,
#                          'location_id': '631098760',
#                          'location_name': 'The AutoShow',
#                          'location_url': 'https://www.instagram.com/explore/locations/631098760/the-autoshow/',
#                          'longitude': -79.3851645044},
#             'tags': ['#car', '#lamborghini', '#toronto', '#canada']},
#            {'caption': 'Keyboards #Keyboard #Korg #Reason #Cubase #Custom '
#                        '#Cool',
#             'comments': 0,
#             'date': '2013-07-03T13:49:51.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/44d63f4bcfbf926506712fc82c81cd90/5BC05D5A/t51.2885-15/e15/11348207_780407655405754_134560801_n.jpg',
#             'likes': 14,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Keyboard',
#                      '#Korg',
#                      '#Reason',
#                      '#Cubase',
#                      '#Custom',
#                      '#Cool']},
#            {'caption': 'Todo listo para las audiciones de mañana del '
#                        '@fihumanidades @andresboissiere @tdmiguel.dpz '
#                        '@hectorale12 #music #musician #me #guitar '
#                        '#electricguitar #ibanez',
#             'comments': 4,
#             'date': '2015-04-26T18:03:58.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/911a506f78aa639ec25ec874cd159ccc/5B21FECB/t51.2885-15/e15/11184460_1645055695730280_310373267_n.jpg',
#             'likes': 29,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#music',
#                      '#musician',
#                      '#me',
#                      '#guitar',
#                      '#electricguitar',
#                      '#ibanez']},
#            {'caption': '#working #me #apple #mac #cool #gopro #system '
#                        '#cinema4D #animation #GrupoASA #csap',
#             'comments': 0,
#             'date': '2015-05-25T18:25:24.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/0568dc13c542d61145a3a168e85a12a1/5BB95701/t51.2885-15/e15/11378236_792032044244671_1032405357_n.jpg',
#             'likes': 16,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#working',
#                      '#me',
#                      '#apple',
#                      '#mac',
#                      '#cool',
#                      '#gopro',
#                      '#system',
#                      '#cinema4D',
#                      '#animation',
#                      '#GrupoASA',
#                      '#csap']},
#            {'caption': 'Memories #me #roland #fantom #keyboard #music '
#                        '#musician',
#             'comments': 0,
#             'date': '2017-02-28T02:06:55.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/952330363245be53bffa07733641fe73/5BB13F32/t51.2885-15/e35/16908715_1899677376927488_882183095732666368_n.jpg',
#             'likes': 35,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#me',
#                      '#roland',
#                      '#fantom',
#                      '#keyboard',
#                      '#music',
#                      '#musician']},
#            {'caption': 'Saliendo para las audiciones de musica del #FILA2015 '
#                        '#SBProject #keyboards',
#             'comments': 0,
#             'date': '2015-05-23T12:40:28.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/9ddb385e15517922d850ad9476fe545f/5BAC350C/t51.2885-15/e15/11378772_1595399197405659_986839513_n.jpg',
#             'likes': 17,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#FILA2015', '#SBProject', '#keyboards']},
#            {'caption': '#Gopro #camera #actioncamera',
#             'comments': 4,
#             'date': '2017-01-29T13:37:39.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/81e5b54eb82e5d8c3ffebb9c6614d3cf/5BAF83BE/t51.2885-15/e35/16123199_1104770629652122_3372761753677987840_n.jpg',
#             'likes': 25,
#             'location': {'latitude': 43.7166,
#                          'location_id': '212991559',
#                          'location_name': 'Toronto, Ontario',
#                          'location_url': 'https://www.instagram.com/explore/locations/212991559/toronto-ontario/',
#                          'longitude': -79.3407},
#             'tags': ['#Gopro', '#camera', '#actioncamera']},
#            {'caption': 'Music store! #guitar #me #music #cool',
#             'comments': 0,
#             'date': '2017-02-03T23:28:19.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/159055141875b969df7d45adbc554ce1/5BA4EEFC/t51.2885-15/e35/16464851_372659733090663_9033067168454934528_n.jpg',
#             'likes': 40,
#             'location': {'latitude': 43.7166,
#                          'location_id': '212991559',
#                          'location_name': 'Toronto, Ontario',
#                          'location_url': 'https://www.instagram.com/explore/locations/212991559/toronto-ontario/',
#                          'longitude': -79.3407},
#             'tags': ['#guitar', '#me', '#music', '#cool']},
#            {'caption': 'Marco Sfogli - Genius 🎹🎸 #tbt #music #me #art #guitar '
#                        '#electricguitar #ibanez #korg #yamaha #ipad #mac '
#                        '#apple #keyboard #rock #rockprog #logicprox '
#                        '#finalcutpro',
#             'comments': 0,
#             'date': '2017-02-15T02:27:21.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/348a0dfd23de70e920d1c32e0616ada9/5B21FFD9/t51.2885-15/e15/16789192_1259726690778302_776099868832694272_n.jpg',
#             'likes': 115,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#tbt',
#                      '#music',
#                      '#me',
#                      '#art',
#                      '#guitar',
#                      '#electricguitar',
#                      '#ibanez',
#                      '#korg',
#                      '#yamaha',
#                      '#ipad',
#                      '#mac',
#                      '#apple',
#                      '#keyboard',
#                      '#rock',
#                      '#rockprog',
#                      '#logicprox',
#                      '#finalcutpro']},
#            {'caption': '#Brothers #Friends #graduación #Cool',
#             'comments': 0,
#             'date': '2015-08-01T14:32:53.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/e6a5e875e0f4169003b95730b7c56ae2/5BB357F2/t51.2885-15/e35/11410433_1656027331275812_395950384_n.jpg',
#             'likes': 27,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Brothers', '#Friends', '#graduaci', '#Cool']},
#            {'caption': '#Music #Musican #Keyboard #Keyboard #Korg #Oasys '
#                        '#Kronos #Triton #Programming #88Keys #61keys '
#                        '#InTheStudio',
#             'comments': 0,
#             'date': '2013-04-20T12:46:13.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/3d2c897c44835c66a8892b880296ab64/5BA1794D/t51.2885-15/e15/11247768_655504964481738_978856916_n.jpg',
#             'likes': 17,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Music',
#                      '#Musican',
#                      '#Keyboard',
#                      '#Keyboard',
#                      '#Korg',
#                      '#Oasys',
#                      '#Kronos',
#                      '#Triton',
#                      '#Programming',
#                      '#88Keys',
#                      '#61keys',
#                      '#InTheStudio']},
#            {'caption': 'Improvisando con @valeriaarellan_ 😍😍😍',
#             'comments': 4,
#             'date': '2015-05-10T00:27:15.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/0c688c9b0f8dc826f55c2490a36587da/5B226105/t51.2885-15/e15/11252102_100740450262649_1952812024_n.jpg',
#             'likes': 20,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#music', '#piano', '#cool', '#duet']},
#            {'caption': 'Playing cool clean guitar riff #guitar #ibanez #cool '
#                        '#tagsforlikes #me #music #musician #macbook #boss',
#             'comments': 1,
#             'date': '2014-09-07T23:57:00.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/db4db4a0f4be86f52dfef980cfb04f57/5B22CBA3/t51.2885-15/e15/10617044_926506400697417_481316647_n.jpg',
#             'likes': 25,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#guitar',
#                      '#ibanez',
#                      '#cool',
#                      '#tagsforlikes',
#                      '#me',
#                      '#music',
#                      '#musician',
#                      '#macbook',
#                      '#boss']},
#            {'caption': 'Testing #boss #pedalboard #harmonist #music #me #rock '
#                        '#guitar #ibanez #electricguitar #solo #cool '
#                        '#tagsforlikes',
#             'comments': 2,
#             'date': '2014-09-15T22:29:07.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/0361c33f2dd88eb2ce2b3f242bc8018b/5B220CD4/t51.2885-15/e15/10707019_525354157596173_265785_n.jpg',
#             'likes': 43,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#boss',
#                      '#pedalboard',
#                      '#harmonist',
#                      '#music',
#                      '#me',
#                      '#rock',
#                      '#guitar',
#                      '#ibanez',
#                      '#electricguitar',
#                      '#solo',
#                      '#cool',
#                      '#tagsforlikes']},
#            {'caption': '#Music #Art #Lifestyle #Amazing #Castle @lakesfrhat',
#             'comments': 2,
#             'date': '2013-04-20T10:36:14.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/07073a14a79fdd9ab16cc9c48857fc58/5BA27734/t51.2885-15/e15/11272448_1445842739063346_1035199782_n.jpg',
#             'likes': 16,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Music', '#Art', '#Lifestyle', '#Amazing', '#Castle']},
#            {'caption': '#Music #Musican #Keyboard #Keyboard #Keyboard #Korg '
#                        '#Kronos #61keys #VSTi #piano #Moog #16gbRam '
#                        '#Programming #Windows 8 #Virtual #instruments '
#                        '#Interface #Midi #SoundLibrary #Cubase #customkeyboard',
#             'comments': 0,
#             'date': '2013-04-20T20:46:35.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/a620ff102518c70780f061d865cddd38/5BAB84AF/t51.2885-15/e15/11312448_1438159393155160_173069015_n.jpg',
#             'likes': 25,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Music',
#                      '#Musican',
#                      '#Keyboard',
#                      '#Keyboard',
#                      '#Keyboard',
#                      '#Korg',
#                      '#Kronos',
#                      '#61keys',
#                      '#VSTi',
#                      '#piano',
#                      '#Moog',
#                      '#16gbRam',
#                      '#Programming',
#                      '#Windows',
#                      '#Virtual',
#                      '#instruments',
#                      '#Interface',
#                      '#Midi',
#                      '#SoundLibrary',
#                      '#Cubase',
#                      '#customkeyboard']},
#            {'caption': 'Playing Drums #Drums #Tama #Cool #Music #Me #Composing '
#                        '#Recording',
#             'comments': 0,
#             'date': '2013-07-20T04:42:56.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/0aec673f69ab83e518a02d77084329eb/5BBC5A9D/t51.2885-15/e15/11357963_1609728479307844_1941132587_n.jpg',
#             'likes': 12,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Drums',
#                      '#Tama',
#                      '#Cool',
#                      '#Music',
#                      '#Me',
#                      '#Composing',
#                      '#Recording']},
#            {'caption': 'Keyboard Solo!!!! #Keyboard #Korg #Reason5 '
#                        '#CustomKeyboard #Cool #Art #Music #Solo #Lead #Band',
#             'comments': 5,
#             'date': '2013-07-06T19:49:00.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/b18f2d036e605a376481df143225d055/5B2295E9/t51.2885-15/e15/11325148_852497538152855_1695305812_n.jpg',
#             'likes': 19,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Keyboard',
#                      '#Korg',
#                      '#Reason5',
#                      '#CustomKeyboard',
#                      '#Cool',
#                      '#Art',
#                      '#Music',
#                      '#Solo',
#                      '#Lead',
#                      '#Band']},
#            {'caption': '#Music #thebeatles #Piano #FourHands #LetItBe '
#                        '#steinwain #cool #art #impro',
#             'comments': 2,
#             'date': '2015-07-10T20:04:07.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/6587df24a446060e416dd3cac8353d24/5B2296DC/t51.2885-15/e15/10608038_1435679813424871_1885543497_n.jpg',
#             'likes': 23,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Music',
#                      '#thebeatles',
#                      '#Piano',
#                      '#FourHands',
#                      '#LetItBe',
#                      '#steinwain',
#                      '#cool',
#                      '#art',
#                      '#impro']},
#            {'caption': 'My own mark #developer #animation #music #cool #me #hp '
#                        '#galaxys7 #pro',
#             'comments': 6,
#             'date': '2017-02-04T01:54:33.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/f88e070ff8ccdb46f71161400ac78929/5BA88DBF/t51.2885-15/e35/16228851_1218572694865077_4442558551432364032_n.jpg',
#             'likes': 31,
#             'location': {'latitude': 43.7166,
#                          'location_id': '212991559',
#                          'location_name': 'Toronto, Ontario',
#                          'location_url': 'https://www.instagram.com/explore/locations/212991559/toronto-ontario/',
#                          'longitude': -79.3407},
#             'tags': ['#developer',
#                      '#animation',
#                      '#music',
#                      '#cool',
#                      '#me',
#                      '#hp',
#                      '#galaxys7',
#                      '#pro']},
#            {'caption': 'CryptoTeam! #cool #team #melia #hotel #bussiness',
#             'comments': 3,
#             'date': '2016-12-28T19:26:41.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/70fcbc85d345ee2f1a6e2f8e757bd6ba/5BBB69CD/t51.2885-15/e35/15802014_241163156307291_228256754205458432_n.jpg',
#             'likes': 146,
#             'location': {'latitude': 10.4924393769,
#                          'location_id': '214790531',
#                          'location_name': 'Gran Meliá Caracas',
#                          'location_url': 'https://www.instagram.com/explore/locations/214790531/gran-melia-caracas/',
#                          'longitude': -66.8778541999},
#             'tags': ['#cool', '#team', '#melia', '#hotel', '#bussiness']},
#            {'caption': 'Hello, ladies #nvidia #titanx #pascal #graphics '
#                        '#animation #computer #computerscience',
#             'comments': 6,
#             'date': '2017-01-27T21:51:03.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/ec7e0c76e946ec2c3cffa37fc070ac7f/5BB630BE/t51.2885-15/e35/16123804_1121927137919889_3888786767028944896_n.jpg',
#             'likes': 49,
#             'location': {'latitude': 43.7166,
#                          'location_id': '212991559',
#                          'location_name': 'Toronto, Ontario',
#                          'location_url': 'https://www.instagram.com/explore/locations/212991559/toronto-ontario/',
#                          'longitude': -79.3407},
#             'tags': ['#nvidia',
#                      '#titanx',
#                      '#pascal',
#                      '#graphics',
#                      '#animation',
#                      '#computer',
#                      '#computerscience']},
#            {'caption': 'Diseñando mi rack para el #FILA2015 @fundapromusik '
#                        '@festival_fila #music #drawing #procreate #keyboards '
#                        '#midi #roland',
#             'comments': 6,
#             'date': '2015-03-28T22:24:36.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/283aa2b5f8edda6706e37b76a73bd3ee/5B226142/t51.2885-15/e15/11004977_1602509333322990_1433655448_n.jpg',
#             'likes': 25,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#FILA2015',
#                      '#music',
#                      '#drawing',
#                      '#procreate',
#                      '#keyboards',
#                      '#midi',
#                      '#roland']},
#            {'caption': 'Working on an animation #cinema4D #cool #animation '
#                        '#working #3D',
#             'comments': 4,
#             'date': '2014-11-06T18:56:58.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/b49c15cf365b5e37cd570203fcf0e3fd/5B225F1C/t51.2885-15/e15/10802739_746477305400929_1734924562_n.jpg',
#             'likes': 20,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#cinema4D', '#cool', '#animation', '#working', '#3D']},
#            {'caption': 'Animación para el #FILA2015 parte 2 #helicopter '
#                        '#Caracas #Venezuela #Drone #motionTraking #cinema4D '
#                        '#aftereffects @fundapromusik @festival_fila',
#             'comments': 7,
#             'date': '2015-03-30T02:43:47.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/efddb1ac63d54a9407d4fb5c9d9a8aac/5B22F94D/t51.2885-15/e15/10616927_880622562005198_1731595648_n.jpg',
#             'likes': 33,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#FILA2015',
#                      '#helicopter',
#                      '#Caracas',
#                      '#Venezuela',
#                      '#Drone',
#                      '#motionTraking',
#                      '#cinema4D',
#                      '#aftereffects']},
#            {'caption': 'Es una broma, Verdad?',
#             'comments': 2,
#             'date': '2013-01-24T00:20:27.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/127a49bbe15e6c923e5c91a5c29860cc/5BB3267B/t51.2885-15/e15/11273055_1589455441324359_1920828314_n.jpg',
#             'likes': 3,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': []},
#            {'caption': "It's cold outside #wheater #canada",
#             'comments': 0,
#             'date': '2017-01-30T11:27:30.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/39f66c24e0608373a8f70082686f95fe/5BB5E9DB/t51.2885-15/e35/16230332_1720009751663021_5593037284799676416_n.jpg',
#             'likes': 11,
#             'location': {'latitude': 43.7166,
#                          'location_id': '212991559',
#                          'location_name': 'Toronto, Ontario',
#                          'location_url': 'https://www.instagram.com/explore/locations/212991559/toronto-ontario/',
#                          'longitude': -79.3407},
#             'tags': ['#wheater', '#canada']},
#            {'caption': 'El Premio #FILA2013 #Music #Cool #Winners',
#             'comments': 0,
#             'date': '2013-06-30T11:41:25.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/ebc04512de12008495448d139041cc15/5BA9B3C2/t51.2885-15/e15/11330752_375907705932769_866027384_n.jpg',
#             'likes': 9,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#FILA2013', '#Music', '#Cool', '#Winners']},
#            {'caption': '#alterbridge #waterrising #me #music #musician #cool '
#                        '#cover #keyboard #electricguitar #guitar #apple #ipad '
#                        '#repost #mac #macbook #macpro #rock #myroland',
#             'comments': 9,
#             'date': '2015-04-23T21:22:20.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/32efd5fdabcd5e659a70365478ef7874/5B22C37B/t51.2885-15/e15/11189752_1650392165188882_68300509_n.jpg',
#             'likes': 36,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#alterbridge',
#                      '#waterrising',
#                      '#me',
#                      '#music',
#                      '#musician',
#                      '#cool',
#                      '#cover',
#                      '#keyboard',
#                      '#electricguitar',
#                      '#guitar',
#                      '#apple',
#                      '#ipad',
#                      '#repost',
#                      '#mac',
#                      '#macbook',
#                      '#macpro',
#                      '#rock',
#                      '#myroland']},
#            {'caption': '#keyboard #Workstation #Korg #Kronos #Music #Art '
#                        '#RockProg #Programming #Profesional #HomeStudio #Cool',
#             'comments': 0,
#             'date': '2013-06-22T12:28:07.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/e220a50d4b69f8b61a49fabf0ca08048/5BAE3EB1/t51.2885-15/e15/11379790_1434258323547861_1413562181_n.jpg',
#             'likes': 22,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#keyboard',
#                      '#Workstation',
#                      '#Korg',
#                      '#Kronos',
#                      '#Music',
#                      '#Art',
#                      '#RockProg',
#                      '#Programming',
#                      '#Profesional',
#                      '#HomeStudio',
#                      '#Cool']},
#            {'caption': '#ibanez #Ibanez #Ibanez #Prestige #Guitar #music',
#             'comments': 2,
#             'date': '2013-05-03T00:09:06.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/83c6ebeff712b13747edfe16ed0db113/5BB3F61F/t51.2885-15/e15/11267838_863116020413399_192690059_n.jpg',
#             'likes': 12,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#ibanez',
#                      '#Ibanez',
#                      '#Ibanez',
#                      '#Prestige',
#                      '#Guitar',
#                      '#music']},
#            {'caption': 'Waters Rising - Alter Bridge #rock #me #guitar '
#                        '#electricguitar #piano #homestudio #keyboard #korg '
#                        '#mac #ipad',
#             'comments': 4,
#             'date': '2017-02-26T00:19:13.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/e35c67855629df9402e8c1374ded07d7/5B2203BB/t51.2885-15/e15/16906864_1389609011101544_28440088023138304_n.jpg',
#             'likes': 154,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#rock',
#                      '#me',
#                      '#guitar',
#                      '#electricguitar',
#                      '#piano',
#                      '#homestudio',
#                      '#keyboard',
#                      '#korg',
#                      '#mac',
#                      '#ipad']},
#            {'caption': 'Me and my Custom Keyboard #CustomKeyboard #Korg #Dell '
#                        '#Apple #iPad #Reason #Cool',
#             'comments': 0,
#             'date': '2013-07-06T12:28:41.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/c34bd30794adff560ce9c79f82033414/5BC175D4/t51.2885-15/e15/11351681_380233648851167_855962982_n.jpg',
#             'likes': 5,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#CustomKeyboard',
#                      '#Korg',
#                      '#Dell',
#                      '#Apple',
#                      '#iPad',
#                      '#Reason',
#                      '#Cool']},
#            {'caption': 'In the studio! #Me #Profesional #Keyboards #music '
#                        '#Musician #Vintage #Art #RockProg #Ibanez #Mesabooguie '
#                        '#Amps #Noise',
#             'comments': 0,
#             'date': '2013-05-29T00:07:38.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/0b841a0eba7f0acd3e99a569b6a3b6ab/5BAF674C/t51.2885-15/e15/11352920_354750891399064_1448379419_n.jpg',
#             'likes': 18,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Me',
#                      '#Profesional',
#                      '#Keyboards',
#                      '#music',
#                      '#Musician',
#                      '#Vintage',
#                      '#Art',
#                      '#RockProg',
#                      '#Ibanez',
#                      '#Mesabooguie',
#                      '#Amps',
#                      '#Noise']},
#            {'caption': 'JavaScript Canvas SVG Drawing! #javascript #graphics '
#                        '#computergraphics',
#             'comments': 3,
#             'date': '2017-01-13T00:03:45.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/4d59feb18b21290285b8c414fad343ec/5B22C59B/t51.2885-15/e15/15877618_1223654311022188_579549258991009792_n.jpg',
#             'likes': 147,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#javascript', '#graphics', '#computergraphics']},
#            {'caption': '#night',
#             'comments': 0,
#             'date': '2015-05-16T15:00:45.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/b1e03cb48df2404ae4b5290bd4754b29/5BA218C5/t51.2885-15/e15/11272949_500842930063574_941650943_n.jpg',
#             'likes': 15,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#night']},
#            {'caption': '#Render Time! #ucab #caracas #venezuela #3DAnimation '
#                        '#Cinema4D #computerscience #graphics #nvidia #intel '
#                        '#workstation',
#             'comments': 1,
#             'date': '2016-01-23T17:33:04.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/54796e7a6d39d6eed6b1e110fe4efebe/5BB7D86D/t51.2885-15/e35/12552213_181422812216787_205342932_n.jpg',
#             'likes': 42,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Render',
#                      '#ucab',
#                      '#caracas',
#                      '#venezuela',
#                      '#3DAnimation',
#                      '#Cinema4D',
#                      '#computerscience',
#                      '#graphics',
#                      '#nvidia',
#                      '#intel',
#                      '#workstation']},
#            {'caption': 'Pasándola bien entre amigos! #music #cool #Friends '
#                        '#cool #drums #brothers #rock #art #myroland',
#             'comments': 2,
#             'date': '2015-09-17T17:05:49.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/152bb7e4e20ba8178d37927903220082/5BA73F35/t51.2885-15/e35/11262755_1612730008988975_963392698_n.jpg',
#             'likes': 27,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#music',
#                      '#cool',
#                      '#Friends',
#                      '#cool',
#                      '#drums',
#                      '#brothers',
#                      '#rock',
#                      '#art',
#                      '#myroland']},
#            {'caption': 'Haciendo un robot #Robot #Programing #Arduino '
#                        '#Creative #Windows #RaspberryPI #Cool #Developer',
#             'comments': 2,
#             'date': '2013-08-16T00:32:48.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/9c9614dd27679095fbb20e8378cc9e6a/5BB01175/t51.2885-15/e15/11357011_835617029856226_1730323166_n.jpg',
#             'likes': 21,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Robot',
#                      '#Programing',
#                      '#Arduino',
#                      '#Creative',
#                      '#Windows',
#                      '#RaspberryPI',
#                      '#Cool',
#                      '#Developer']},
#            {'caption': 'The Mixer #Mixing #Studio #MacPro #Music',
#             'comments': 0,
#             'date': '2013-07-03T13:45:47.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/3c61d4aed58ff3fbf1d0163f4b2e187e/5BB849A0/t51.2885-15/e15/11348098_847221495366641_379522628_n.jpg',
#             'likes': 14,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Mixing', '#Studio', '#MacPro', '#Music']},
#            {'caption': 'Hmm #Troll',
#             'comments': 0,
#             'date': '2013-09-25T11:29:58.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/8a374570b2e1ca793cbfaa1cbdcf10a5/5B9F924E/t51.2885-15/e15/11258360_823634251055432_102771605_n.jpg',
#             'likes': 6,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Troll']},
#            {'caption': 'My Desktop today! #desktop #computer #apple #mac '
#                        '#microsoft #unix #linux #apple #nokia #aoc #htc #dell '
#                        '#macbook #engineer #cool #ipad #music #editing #photo '
#                        '#windows',
#             'comments': 8,
#             'date': '2014-08-23T20:55:58.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/7f59f442e8835569d505f44636b49125/5BB5B72D/t51.2885-15/e15/917201_763323847059888_549906833_n.jpg',
#             'likes': 25,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#desktop',
#                      '#computer',
#                      '#apple',
#                      '#mac',
#                      '#microsoft',
#                      '#unix',
#                      '#linux',
#                      '#apple',
#                      '#nokia',
#                      '#aoc',
#                      '#htc',
#                      '#dell',
#                      '#macbook',
#                      '#engineer',
#                      '#cool',
#                      '#ipad',
#                      '#music',
#                      '#editing',
#                      '#photo',
#                      '#windows']},
#            {'caption': 'Prototyping #Rails #arduino #Raspberrypi #asus #nvidia '
#                        '#developerlife',
#             'comments': 0,
#             'date': '2017-02-24T16:00:27.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/8b7d1b53d9e646d2bf9c2dd90c60e7cb/5BA0AF50/t51.2885-15/e35/16908785_1262823173835283_3112810060678430720_n.jpg',
#             'likes': 14,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Rails',
#                      '#arduino',
#                      '#Raspberrypi',
#                      '#asus',
#                      '#nvidia',
#                      '#developerlife']},
#            {'caption': 'Backyard timelapse! #backyard #timelapse #cool #canada '
#                        '#toronto #snow',
#             'comments': 2,
#             'date': '2017-02-20T02:32:59.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/95a4080504077d93f68cf11ba424def1/5B22C934/t51.2885-15/e15/16583343_423811687963058_4477425615632334848_n.jpg',
#             'likes': 90,
#             'location': {'latitude': 43.7166,
#                          'location_id': '212991559',
#                          'location_name': 'Toronto, Ontario',
#                          'location_url': 'https://www.instagram.com/explore/locations/212991559/toronto-ontario/',
#                          'longitude': -79.3407},
#             'tags': ['#backyard',
#                      '#timelapse',
#                      '#cool',
#                      '#canada',
#                      '#toronto',
#                      '#snow']},
#            {'caption': '#SBProject #Music #me #gopro #myRoland #ibanez #rock '
#                        '#rockprog #music',
#             'comments': 0,
#             'date': '2015-06-15T14:16:17.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/a6a5447940687b987701327e152cdd6d/5B21FCA5/t51.2885-15/e15/11311268_117502438584135_40489895_n.jpg',
#             'likes': 24,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#SBProject',
#                      '#Music',
#                      '#me',
#                      '#gopro',
#                      '#myRoland',
#                      '#ibanez',
#                      '#rock',
#                      '#rockprog',
#                      '#music']},
#            {'caption': '#SBProject #Music #Me #cool #music #art #progressive '
#                        '#venezuela #caracas #ibanez #myroland #mainstage #show',
#             'comments': 4,
#             'date': '2015-06-14T20:15:41.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/407b766de4ac8aa9d65c7521d92c9ac1/5B22C569/t51.2885-15/e15/11419010_704459746327117_1462121741_n.jpg',
#             'likes': 31,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#SBProject',
#                      '#Music',
#                      '#Me',
#                      '#cool',
#                      '#music',
#                      '#art',
#                      '#progressive',
#                      '#venezuela',
#                      '#caracas',
#                      '#ibanez',
#                      '#myroland',
#                      '#mainstage',
#                      '#show']},
#            {'caption': 'Extreme router + 1Gbps internet connection! #asus '
#                        '#router #1gbps #internet #networking',
#             'comments': 17,
#             'date': '2017-02-17T01:29:51.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/d17a1f9fdeb05308194e7348a2553d6a/5BC09466/t51.2885-15/e35/16584901_1295916710457399_4558707021305610240_n.jpg',
#             'likes': 60,
#             'location': {'latitude': 43.7166,
#                          'location_id': '212991559',
#                          'location_name': 'Toronto, Ontario',
#                          'location_url': 'https://www.instagram.com/explore/locations/212991559/toronto-ontario/',
#                          'longitude': -79.3407},
#             'tags': ['#asus', '#router', '#1gbps', '#internet', '#networking']},
#            {'caption': 'Solo de piano 1 #Solo #Piano #Music #Korg #RockProg '
#                        '#Cubase5 #Pianissimo #Windows',
#             'comments': 0,
# ...
#                      '#fila2015',
#                      '#me',
#                      '#music',
#                      '#myroland',
#                      '#keyboard',
#                      '#ibanez',
#                      '#roland',
#                      '#ipad',
#                      '#mainstage',
#                      '#cool',
#                      '#tagsforlikes']},
#            {'caption': 'So much power inside a phone! #nvidia #cloud '
#                        '#computing #server',
#             'comments': 2,
#             'date': '2016-12-18T04:12:29.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/263760275d3b525d437daf1759d973d9/5BA38C3F/t51.2885-15/s1080x1080/e15/fr/15403400_1898985353667606_2695162269674766336_n.jpg',
#             'likes': 31,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#nvidia', '#cloud', '#computing', '#server']},
#            {'caption': 'Llegó el día!!! Último día!! #graduación #csap',
#             'comments': 10,
#             'date': '2015-06-29T12:00:14.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/eb45f79eb56de02552e520e40e8bb7bd/5BA86D12/t51.2885-15/e15/11327289_779103102189024_297200848_n.jpg',
#             'likes': 29,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#graduaci', '#csap']},
#            {'caption': 'Programando para la XVI Cumbre del Colegio San Agustín '
#                        'el Paraíso @oscarb1110 #programming #cool #macintosh '
#                        '#mac #apple #ipad #visualstudio #windows #hackintosh '
#                        '#cool #me #goprohero #go #gopro',
#             'comments': 1,
#             'date': '2015-05-27T01:19:49.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/e16ae965f0a10dff873dfcd9ae803dcd/5BA5C053/t51.2885-15/e15/11246912_944280795594978_900417089_n.jpg',
#             'likes': 24,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#programming',
#                      '#cool',
#                      '#macintosh',
#                      '#mac',
#                      '#apple',
#                      '#ipad',
#                      '#visualstudio',
#                      '#windows',
#                      '#hackintosh',
#                      '#cool',
#                      '#me',
#                      '#goprohero',
#                      '#go',
#                      '#gopro']},
#            {'caption': '#familytime #happynewyear',
#             'comments': 0,
#             'date': '2016-01-01T03:49:57.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/19f8c65c9dbf6ec718af3a138344b96c/5BB976AE/t51.2885-15/e35/12353213_1548721315449732_1990519340_n.jpg',
#             'likes': 27,
#             'location': {'latitude': 10.4924393769,
#                          'location_id': '214790531',
#                          'location_name': 'Gran Meliá Caracas',
#                          'location_url': 'https://www.instagram.com/explore/locations/214790531/gran-melia-caracas/',
#                          'longitude': -66.8778541999},
#             'tags': ['#familytime', '#happynewyear']},
#            {'caption': '#SonityWolf team!',
#             'comments': 3,
#             'date': '2017-01-06T17:39:30.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/cca49b953fdac7fe1ea428def7db8d9c/5BBAD42E/t51.2885-15/e35/15803566_251000215321820_7032599091355844608_n.jpg',
#             'likes': 140,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#SonityWolf', '#LacrasOnly']},
#            {'caption': 'Developing Facial Recognition app #tensorflow '
#                        '#developer #machinelearning #artificialintelligence '
#                        '#me #cool #programming #linux',
#             'comments': 10,
#             'date': '2016-11-28T02:30:29.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/b2941d65370e20843656d9a35e1fd6d7/5BB6D3F5/t51.2885-15/e35/15099548_339617473082294_5953085376770867200_n.jpg',
#             'likes': 222,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#tensorflow',
#                      '#developer',
#                      '#machinelearning',
#                      '#artificialintelligence',
#                      '#me',
#                      '#cool',
#                      '#programming',
#                      '#linux']},
#            {'caption': 'Gato consentido #Cat #Apple #iPad #Fun #Cool',
#             'comments': 1,
#             'date': '2013-09-11T02:05:25.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/ffc2475b859aa92674a8438fdae92784/5BB32038/t51.2885-15/e15/11373568_728118263964354_1743287343_n.jpg',
#             'likes': 5,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Cat', '#Apple', '#iPad', '#Fun', '#Cool']},
#            {'caption': '#Relax #pool #vacations #Caracas #venezuela',
#             'comments': 0,
#             'date': '2016-12-28T14:58:52.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/b510ade11a7bac900724850a910649d1/5B22B799/t51.2885-15/e15/15253147_1806065396298791_4794745032185741312_n.jpg',
#             'likes': 57,
#             'location': {'latitude': 10.4924393769,
#                          'location_id': '214790531',
#                          'location_name': 'Gran Meliá Caracas',
#                          'location_url': 'https://www.instagram.com/explore/locations/214790531/gran-melia-caracas/',
#                          'longitude': -66.8778541999},
#             'tags': ['#Relax',
#                      '#pool',
#                      '#vacations',
#                      '#Caracas',
#                      '#venezuela']},
#            {'caption': 'Practicing a little bit :) #piano #ipad #korg '
#                        '#myroland #stage #cool #sampletank #steinway #samples '
#                        '#me #music #art #apple #samplewiz #iphoneonly '
#                        '#tagsforlikes #followme',
#             'comments': 9,
#             'date': '2014-09-01T15:39:41.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/4073421f9f7c069a69d52711a3ce058a/5B22AE74/t51.2885-15/e15/10661026_700949819992430_585515476_n.jpg',
#             'likes': 33,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#piano',
#                      '#ipad',
#                      '#korg',
#                      '#myroland',
#                      '#stage',
#                      '#cool',
#                      '#sampletank',
#                      '#steinway',
#                      '#samples',
#                      '#me',
#                      '#music',
#                      '#art',
#                      '#apple',
#                      '#samplewiz',
#                      '#iphoneonly',
#                      '#tagsforlikes',
#                      '#followme']},
#            {'caption': 'ThrowBack! #music #musician #rock #rockprog #guitar '
#                        '#electricguitar #ibanez #boss #roland #keyboard #korg '
#                        '#mac #apple #ipad #virtualdrums #cool #edited '
#                        '#logicprox #cover #finalcutpro #sfogli #genius #bass '
#                        '#bassplayer #guitarplayer #venezuela #caracas',
#             'comments': 8,
#             'date': '2014-08-15T15:29:20.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/578a91bfff20c605b5b40d891c878bae/5B22E6E9/t51.2885-15/e15/10598669_357096031108837_1847202907_n.jpg',
#             'likes': 59,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#music',
#                      '#musician',
#                      '#rock',
#                      '#rockprog',
#                      '#guitar',
#                      '#electricguitar',
#                      '#ibanez',
#                      '#boss',
#                      '#roland',
#                      '#keyboard',
#                      '#korg',
#                      '#mac',
#                      '#apple',
#                      '#ipad',
#                      '#virtualdrums',
#                      '#cool',
#                      '#edited',
#                      '#logicprox',
#                      '#cover',
#                      '#finalcutpro',
#                      '#sfogli',
#                      '#genius',
#                      '#bass',
#                      '#bassplayer',
#                      '#guitarplayer',
#                      '#venezuela',
#                      '#caracas']},
#            {'caption': 'Inside a piano #Piano #Music #Strings #Yamaha',
#             'comments': 0,
#             'date': '2013-10-02T00:26:09.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/782ce74e7baf525f15a8e576b36bad4b/5BA920AF/t51.2885-15/e15/11325117_648486825286495_327471385_n.jpg',
#             'likes': 5,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Piano', '#Music', '#Strings', '#Yamaha']},
#            {'caption': 'Cloud Computing magic! A phone with 64 logical '
#                        'processors and 128 gigs of ram! #microsoft #rdp '
#                        '#android #samsung #servers #windows #nvidia',
#             'comments': 3,
#             'date': '2017-02-10T04:25:33.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/3356a5c1c73a85655a95f887fb954373/5BB3BBFD/t51.2885-15/e35/16464893_1421349694565838_1565073502703190016_n.jpg',
#             'likes': 19,
#             'location': {'latitude': 43.7166,
#                          'location_id': '212991559',
#                          'location_name': 'Toronto, Ontario',
#                          'location_url': 'https://www.instagram.com/explore/locations/212991559/toronto-ontario/',
#                          'longitude': -79.3407},
#             'tags': ['#microsoft',
#                      '#rdp',
#                      '#android',
#                      '#samsung',
#                      '#servers',
#                      '#windows',
#                      '#nvidia']},
#            {'caption': '#Repost @andreaaigliozzi\n'
#                        '・・・\n'
#                        'El viernes 12 de junio a las 7 pm en teatrex el bosque '
#                        'no te puedes perder la obra PROYECTO ROJO, te imaginas '
#                        'que te fueran arrebatadas las capacidades de pensar, '
#                        'recordar y sentir? @festival_fila',
#             'comments': 0,
#             'date': '2015-06-04T23:32:39.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/8c18dac6ad6143d3aa89431e029e2c9d/5B22F552/t51.2885-15/e15/11373581_968513989866624_1717581050_n.jpg',
#             'likes': 6,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Repost']},
#            {'caption': 'Keyboard and guitar Player!!! #me #music #cool #haken '
#                        '#insomnia #rock #prog #rockprog #keyboard #korg '
#                        '#sampletank #ipad #homestudio #tagsforlikes',
#             'comments': 1,
#             'date': '2015-04-05T17:34:12.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/c19634f694418e3fca1eef2b09b0974a/5B22CEB6/t51.2885-15/e15/11117002_905796882805269_1832488316_n.jpg',
#             'likes': 28,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#me',
#                      '#music',
#                      '#cool',
#                      '#haken',
#                      '#insomnia',
#                      '#rock',
#                      '#prog',
#                      '#rockprog',
#                      '#keyboard',
#                      '#korg',
#                      '#sampletank',
#                      '#ipad',
#                      '#homestudio',
#                      '#tagsforlikes']},
#            {'caption': '#Cubase #MicroStudio #CustomKeyboard #Reason5 #Midi '
#                        '#SoundLibrary #Programming #RockProg #Dell #composing '
#                        '#Recording #Upload',
#             'comments': 0,
#             'date': '2013-04-20T13:32:17.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/22ca07061425b7d335298bd272ed2ba6/5BBB9288/t51.2885-15/e15/11333388_1596315160627195_2009766372_n.jpg',
#             'likes': 20,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#Cubase',
#                      '#MicroStudio',
#                      '#CustomKeyboard',
#                      '#Reason5',
#                      '#Midi',
#                      '#SoundLibrary',
#                      '#Programming',
#                      '#RockProg',
#                      '#Dell',
#                      '#composing',
#                      '#Recording',
#                      '#Upload']},
#            {'caption': 'El clan',
#             'comments': 0,
#             'date': '2015-05-14T18:49:54.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/fc936c8e7f7f1366640a347ce7d46c96/5BB27DEF/t51.2885-15/e15/11265765_1595125674105513_575630629_n.jpg',
#             'likes': 17,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': []},
#            {'caption': 'Nos vemos el viernes 12 de junio en el teatrex el '
#                        'bosque!!! #GrupoASA #working #theater #cool',
#             'comments': 0,
#             'date': '2015-05-28T11:16:34.000Z',
#             'img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/1d10af9423fa31ba92cf834f0b2167a9/5BAD4297/t51.2885-15/e15/11327218_730127970432153_692778144_n.jpg',
#             'likes': 18,
#             'location': {'latitude': '',
#                          'location_id': 0,
#                          'location_name': '',
#                          'location_url': '',
#                          'longitude': ''},
#             'tags': ['#GrupoASA', '#working', '#theater', '#cool']}],
#  'prof_img': 'https://instagram.fybz2-2.fna.fbcdn.net/vp/e364ab278dfdb52ccb49f2636b863191/5BBBA651/t51.2885-19/s150x150/31310770_205306846925749_5662806588981772288_n.jpg',
#  'username': 'andtek.pro'}

# %%
#Get All Tags
all_tags = []

for post in data['posts']:
    all_tags += post['tags']

print(all_tags)
# Out:
# ['#friday', '#funtime', '#Friends', '#cool', '#love', '#GrupoASA', '#FILA2015', '#cool', '#music', '#keyboards', '#teatro', '#teatrocomprimido', '#me', '#cool', '#computer', '#rockprog', '#mac', '#apple', '#server', '#programming', '#scifi', '#car', '#lamborghini', '#cool', '#interior', '#luxury', '#toronto', '#canada', '#CandyCrush', '#Fail', '#Hack', '#game', '#Videogames', '#mustang', '#car', '#ford', '#interior', '#GrupoASA', '#homeserver', '#hp', '#proliant', '#caracas', '#venezuela', '#1TBofRAM', '#NVIDIA', '#Custom', '#Graphics', '#CallOrText', '#car', '#lamborghini', '#toronto', '#canada', '#Keyboard', '#Korg', '#Reason', '#Cubase', '#Custom', '#Cool', '#music', '#musician', '#me', '#guitar', '#electricguitar', '#ibanez', '#working', '#me', '#apple', '#mac', '#cool', '#gopro', '#system', '#cinema4D', '#animation', '#GrupoASA', '#csap', '#me', '#roland', '#fantom', '#keyboard', '#music', '#musician', '#FILA2015', '#SBProject', '#keyboards', '#Gopro', '#camera', '#actioncamera', '#guitar', '#me', '#music', '#cool', '#tbt', '#music', '#me', '#art', '#guitar', '#electricguitar', '#ibanez', '#korg', '#yamaha', '#ipad', '#mac', '#apple', '#keyboard', '#rock', '#rockprog', '#logicprox', '#finalcutpro', '#Brothers', '#Friends', '#graduaci', '#Cool', '#Music', '#Musican', '#Keyboard', '#Keyboard', '#Korg', '#Oasys', '#Kronos', '#Triton', '#Programming', '#88Keys', '#61keys', '#InTheStudio', '#music', '#piano', '#cool', '#duet', '#guitar', '#ibanez', '#cool', '#tagsforlikes', '#me', '#music', '#musician', '#macbook', '#boss', '#boss', '#pedalboard', '#harmonist', '#music', '#me', '#rock', '#guitar', '#ibanez', '#electricguitar', '#solo', '#cool', '#tagsforlikes', '#Music', '#Art', '#Lifestyle', '#Amazing', '#Castle', '#Music', '#Musican', '#Keyboard', '#Keyboard', '#Keyboard', '#Korg', '#Kronos', '#61keys', '#VSTi', '#piano', '#Moog', '#16gbRam', '#Programming', '#Windows', '#Virtual', '#instruments', '#Interface', '#Midi', '#SoundLibrary', '#Cubase', '#customkeyboard', '#Drums', '#Tama', '#Cool', '#Music', '#Me', '#Composing', '#Recording', '#Keyboard', '#Korg', '#Reason5', '#CustomKeyboard', '#Cool', '#Art', '#Music', '#Solo', '#Lead', '#Band', '#Music', '#thebeatles', '#Piano', '#FourHands', '#LetItBe', '#steinwain', '#cool', '#art', '#impro', '#developer', '#animation', '#music', '#cool', '#me', '#hp', '#galaxys7', '#pro', '#cool', '#team', '#melia', '#hotel', '#bussiness', '#nvidia', '#titanx', '#pascal', '#graphics', '#animation', '#computer', '#computerscience', '#FILA2015', '#music', '#drawing', '#procreate', '#keyboards', '#midi', '#roland', '#cinema4D', '#cool', '#animation', '#working', '#3D', '#FILA2015', '#helicopter', '#Caracas', '#Venezuela', '#Drone', '#motionTraking', '#cinema4D', '#aftereffects', '#wheater', '#canada', '#FILA2013', '#Music', '#Cool', '#Winners', '#alterbridge', '#waterrising', '#me', '#music', '#musician', '#cool', '#cover', '#keyboard', '#electricguitar', '#guitar', '#apple', '#ipad', '#repost', '#mac', '#macbook', '#macpro', '#rock', '#myroland', '#keyboard', '#Workstation', '#Korg', '#Kronos', '#Music', '#Art', '#RockProg', '#Programming', '#Profesional', '#HomeStudio', '#Cool', '#ibanez', '#Ibanez', '#Ibanez', '#Prestige', '#Guitar', '#music', '#rock', '#me', '#guitar', '#electricguitar', '#piano', '#homestudio', '#keyboard', '#korg', '#mac', '#ipad', '#CustomKeyboard', '#Korg', '#Dell', '#Apple', '#iPad', '#Reason', '#Cool', '#Me', '#Profesional', '#Keyboards', '#music', '#Musician', '#Vintage', '#Art', '#RockProg', '#Ibanez', '#Mesabooguie', '#Amps', '#Noise', '#javascript', '#graphics', '#computergraphics', '#night', '#Render', '#ucab', '#caracas', '#venezuela', '#3DAnimation', '#Cinema4D', '#computerscience', '#graphics', '#nvidia', '#intel', '#workstation', '#music', '#cool', '#Friends', '#cool', '#drums', '#brothers', '#rock', '#art', '#myroland', '#Robot', '#Programing', '#Arduino', '#Creative', '#Windows', '#RaspberryPI', '#Cool', '#Developer', '#Mixing', '#Studio', '#MacPro', '#Mus ...

# %%
hashtag_counter = Counter([x.lower() for x in all_tags])

pprint(hashtag_counter)
# Out:
# Counter({'#music': 113,
#          '#cool': 93,
#          '#me': 60,
#          '#keyboard': 46,
#          '#apple': 36,
#          '#korg': 35,
#          '#art': 34,
#          '#ibanez': 33,
#          '#ipad': 31,
#          '#piano': 29,
#          '#musician': 28,
#          '#guitar': 26,
#          '#rockprog': 24,
#          '#roland': 23,
#          '#rock': 19,
#          '#tagsforlikes': 19,
#          '#mac': 17,
#          '#programming': 16,
#          '#myroland': 16,
#          '#canada': 14,
#          '#midi': 14,
#          '#toronto': 12,
#          '#caracas': 12,
#          '#friends': 11,
#          '#venezuela': 11,
#          '#electricguitar': 11,
#          '#recording': 11,
#          '#fila2015': 10,
#          '#animation': 10,
#          '#fantom': 10,
#          '#kronos': 10,
#          '#composing': 10,
#          '#gopro': 9,
#          '#cinema4d': 9,
#          '#musican': 9,
#          '#keyboards': 8,
#          '#nvidia': 8,
#          '#cubase': 8,
#          '#oasys': 8,
#          '#macbook': 8,
#          '#boss': 8,
#          '#windows': 8,
#          '#profesional': 8,
#          '#creative': 8,
#          '#dreamtheater': 8,
#          '#grupoasa': 7,
#          '#logicprox': 7,
#          '#solo': 7,
#          '#customkeyboard': 7,
#          '#working': 6,
#          '#reason5': 6,
#          '#workstation': 6,
#          '#homestudio': 6,
#          '#followme': 6,
#          '#computer': 5,
#          '#graphics': 5,
#          '#reason': 5,
#          '#sbproject': 5,
#          '#yamaha': 5,
#          '#61keys': 5,
#          '#amazing': 5,
#          '#computerscience': 5,
#          '#cover': 5,
#          '#synth': 5,
#          '#swag': 5,
#          '#beautiful': 5,
#          '#instagood': 5,
#          '#car': 4,
#          '#moog': 4,
#          '#drums': 4,
#          '#developer': 4,
#          '#aftereffects': 4,
#          '#repost': 4,
#          '#dell': 4,
#          '#vintage': 4,
#          '#photo': 4,
#          '#asus': 4,
#          '#snow': 4,
#          '#mainstage': 4,
#          '#sonitywolf': 4,
#          '#macbookpro': 4,
#          '#picoftheday': 4,
#          '#android': 4,
#          '#mylife': 4,
#          '#sibelius': 4,
#          '#fun': 4,
#          '#orchestra': 4,
#          '#love': 3,
#          '#hp': 3,
#          '#custom': 3,
#          '#csap': 3,
#          '#tbt': 3,
#          '#88keys': 3,
#          '#virtual': 3,
#          '#soundlibrary': 3,
#          '#impro': 3,
#          '#night': 3,
#          '#programing': 3,
#          '#arduino': 3,
#          '#raspberrypi': 3,
#          '#jordanrudess': 3,
#          '#iphoneonly': 3,
#          '#finalcut': 3,
#          '#concert': 3,
#          '#developers': 3,
#          '#party': 3,
#          '#family': 3,
#          '#keys': 3,
#          '#tensorflow': 3,
#          '#follow': 3,
#          '#happy': 3,
#          '#selfie': 3,
#          '#smile': 3,
#          '#igers': 3,
#          '#follow4follow': 3,
#          '#blue': 3,
#          '#sampletank': 3,
#          '#funtime': 2,
#          '#teatro': 2,
#          '#server': 2,
#          '#lamborghini': 2,
#          '#interior': 2,
#          '#fail': 2,
#          '#homeserver': 2,
#          '#finalcutpro': 2,
#          '#brothers': 2,
#          '#graduaci': 2,
#          '#triton': 2,
#          '#lifestyle': 2,
#          '#vsti': 2,
#          '#16gbram': 2,
#          '#instruments': 2,
#          '#interface': 2,
#          '#lead': 2,
#          '#thebeatles': 2,
#          '#fourhands': 2,
#          '#steinwain': 2,
#          '#3d': 2,
#          '#fila2013': 2,
#          '#alterbridge': 2,
#          '#waterrising': 2,
#          '#macpro': 2,
#          '#mesabooguie': 2,
#          '#amps': 2,
#          '#robot': 2,
#          '#mixing': 2,
#          '#studio': 2,
#          '#microsoft': 2,
#          '#linux': 2,
#          '#nokia': 2,
#          '#engineer': 2,
#          '#rails': 2,
#          '#developerlife': 2,
#          '#progressive': 2,
#          '#macintosh': 2,
#          '#pool': 2,
#          '#familytime': 2,
#          '#ipads': 2,
#          '#screaminghead': 2,
#          '#style': 2,
#          '#ai': 2,
#          '#chill': 2,
#          '#artificialintelligence': 2,
#          '#google': 2,
#          '#lol': 2,
#          '#shirt': 2,
#          '#electric': 2,
#          '#computing': 2,
#          '#starbucks': 2,
#          '#logic': 2,
#          '#sounds': 2,
#          '#samplewiz': 2,
#          '#celo': 2,
#          '#photooftheday': 2,
#          '#like4like': 2,
#          '#summer': 2,
#          '#instadaily': 2,
#          '#fashion': 2,
#          '#instalike': 2,
#          '#food': 2,
#          '#tflers': 2,
#          '#bestoftheday': 2,
#          '#6strings': 2,
#          '#black': 2,
#          '#theater': 2,
#          '#88': 2,
#          '#cute': 2,
#          '#crazy': 2,
#          '#memories': 2,
#          '#life': 2,
#          '#hackintosh': 2,
#          '#niagarafalls': 2,
#          '#pianist': 2,
#          '#bass': 2,
#          '#edit': 2,
#          '#logicpro': 2,
#          '#followback': 2,
#          '#me25': 2,
#          '#cola': 2,
#          '#stage': 2,
#          '#underground': 2,
#          '#friday': 1,
#          '#teatrocomprimido': 1,
#          '#scifi': 1,
#          '#luxury': 1,
#          '#candycrush': 1,
#          '#hack': 1,
#          '#game': 1,
#          '#videogames': 1,
#          '#mustang': 1,
#          '#ford': 1,
#          '#proliant': 1,
#          '#1tbofram': 1,
#          '#callortext': 1,
#          '#system': 1,
#          '#camera': 1,
#          '#actioncamera': 1,
#          '#inthestudio': 1,
#          '#duet': 1,
#          '#pedalboard': 1,
#          '#harmonist': 1,
#          '#castle': 1,
#          '#tama': 1,
#          '#band': 1,
#          '#letitbe': 1,
#          '#galaxys7': 1,
#          '#pro': 1,
#          '#team': 1,
#          '#melia': 1,
#          '#hotel': 1,
#          '#bussiness': 1,
#          '#titanx': 1,
#          '#pascal': 1,
#          '#drawing': 1,
#          '#procreate': 1,
#          '#helicopter': 1,
#          '#drone': 1,
#          '#motiontraking': 1,
#          '#wheater': 1,
#          '#winners': 1,
#          '#prestige': 1,
#          '#noise': 1,
#          '#javascript': 1,
#          '#computergraphics': 1,
#          '#render': 1,
#          '#ucab': 1,
#          '#3danimation': 1,
#          '#intel': 1,
#          '#troll': 1,
#          '#desktop': 1,
#          '#unix': 1,
#          '#aoc': 1,
#          '#htc': 1,
#          '#editing': 1,
#          '#backyard': 1,
#          '#timelapse': 1,
#          '#show': 1,
#          '#router': 1,
#          '#1gbps': 1,
#          '#internet': 1,
#          '#networking': 1,
#          '#cubase5': 1,
#          '#pianissimo': 1,
#          '#effects': 1,
#          '#dad': 1,
#          '#keyboardist': 1,
#          '#palajoda': 1,
#          '#likesforlikes': 1,
#          '#kurzweil': 1,
#          '#fundapromusik': 1,
#          '#conservatory': 1,
#          '#iphone5s': 1,
#          '#musica': 1,
#          '#b': 1,
#          '#colorful': 1,
#          '#hackacademy': 1,
#          '#ios7': 1,
#          '#styletranfer': 1,
#          '#daftpunk': 1,
#          '#funk': 1,
#          '#a33': 1,
#          '#midicontroller': 1,
#          '#bro': 1,
#          '#cntower': 1,
#          '#english': 1,
#          '#criminalminds': 1,
#          '#school': 1,
#          '#wtfaces': 1,
#          '#ipadair': 1,
#          '#experimental': 1,
#          '#neon': 1,
#          '#britmusic': 1,
#          '#practicing': 1,
#          '#app': 1,
#          '#ios': 1,
#          '#garageband': 1,
#          '#violin': 1,
#          '#allineed': 1,
#          '#supermario64': 1,
#          '#mario': 1,
#          '#korggadget': 1,
#          '#korgmodule': 1,
#          '#promo6': 1,
#          '#academiahack': 1,
#          '#titan': 1,
#          '#rendering': 1,
#          '#code': 1,
#          '#lifeisgood': 1,
#          '#composer': 1,
#          '#mymusic': 1,
#          '#yatch': 1,
#          '#playing': 1,
#          '#animals': 1,
#          '#beauty': 1,
#          '#cloudcomputing': 1,
#          '#photoshop': 1,
#          '#nature': 1,
#          '#electronic': 1,
#          '#like': 1,
#          '#ilac': 1,
#          '#festivalfila': 1,
#          '#hobbie': 1,
#          '#protools': 1,
#          '#mixer': 1,
#          '#axiomsolutions': 1,
#          '#goodtimes': 1,
#          '#funny': 1,
#          '#friend': 1,
#          '#best': 1,
#          '#awesome': 1,
#          '#besties': 1,
#          '#picture': 1,
#          '#bestfriend': 1,
#          '#goodfriends': 1,
#          '#forever': 1,
#          '#haha': 1,
#          '#bf': 1,
#          '#bff': 1,
#          '#gf': 1,
#          '#good': 1,
#          '#vocoder': 1,
#          '#houses': 1,
#          '#neighbourhood': 1,
#          '#2015': 1,
#          '#virtualgrand': 1,
#          '#matrix': 1,
#          '#chelo': 1,
#          '#improvisaci': 1,
#          '#hacking': 1,
#          '#cold': 1,
#          '#city': 1,
#          '#broken': 1,
#          '#hate': 1,
#          '#tweegram': 1,
#          '#all': 1,
#          '#artwork': 1,
#          '#sibelius6': 1,
#          '#birthday': 1,
#          '#bday': 1,
#          '#instabday': 1,
#          '#birthdaycake': 1,
#          '#cake': 1,
#          '#celebrate': 1,
#          '#candle': 1,
#          '#candles': 1,
#          '#young': 1,
#          '#old': 1,
#          '#years': 1,
#          '#instacake': 1,
#          '#happybirthday': 1,
#          '#instabirthday': 1,
#          '#born': 1,
#          '#girl': 1,
#          '#hair': 1,
#          '#instamood': 1,
#          '#korgoasys': 1,
#          '#store': 1,
#          '#disks': 1,
#          '#imac': 1,
#          '#dualcam': 1,
#          '#videoediting': 1,
#          '#gibson': 1,
#          '#gift': 1,
#          '#lespaul': 1,
#          '#challenge': 1,
#          '#shot': 1,
#          '#metal': 1,
#          '#macosx': 1,
#          '#collection': 1,
#          '#desing': 1,
#          '#new': 1,
#          '#adobe': 1,
#          '#tarkus': 1,
#          '#master': 1,
#          '#realsports': 1,
#          '#house': 1,
#          '#polisynth': 1,
#          '#mesa': 1,
#          '#amp': 1,
#          '#gameofthrones': 1,
#          '#baldwin': 1,
#          '#backstage': 1,
#          '#jackson': 1,
#          '#guitars': 1,
#          '#7strings': 1,
#          '#musical': 1,
#          '#': 1,
#          '#cam': 1,
#          '#tweak': 1,
#          '#lg': 1,
#          '#4k': 1,
#          '#coll': 1,
#          '#niagara': 1,
#          '#bossa': 1,
#          '#startupweekend': 1,
#          '#sound': 1,
#          '#drummers': 1,
#          '#ezdrummer': 1,
#          '#autodesk': 1,
#          '#maya': 1,
#          '#startup': 1,
#          '#fantomg8': 1,
#          '#efects': 1,
#          '#wah': 1,
#          '#coffee': 1,
#          '#beta': 1,
#          '#python': 1,
#          '#xcode': 1,
#          '#marshall': 1,
#          '#vox': 1,
#          '#symphonic': 1,
#          '#elsistema': 1,
#          '#bossgt10': 1,
#          '#musicproduction': 1,
#          '#maudio': 1,
#          '#tesla': 1,
#          '#her': 1,
#          '#macosxtiger': 1,
#          '#core2duo': 1,
#          '#history': 1,
#          '#2006': 1,
#          '#finder': 1,
#          '#iphoto': 1,
#          '#research': 1,
#          '#hammond': 1,
#          '#vdrums': 1,
#          '#oldhomestudio': 1,
#          '#juno': 1,
#          '#casio': 1,
#          '#cloud': 1,
#          '#visualstudio': 1,
#          '#goprohero': 1,
#          '#go': 1,
#          '#happynewyear': 1,
#          '#lacrasonly': 1,
#          '#machinelearning': 1,
#          '#cat': 1,
#          '#relax': 1,
#          '#vacations': 1,
#          '#steinway': 1,
#          '#samples': 1,
#          '#virtualdrums': 1,
#          '#edited': 1,
#          '#sfogli': 1,
#          '#genius': 1,
#          '#bassplayer': 1,
#          '#guitarplayer': 1,
#          '#strings': 1,
#          '#rdp': 1,
#          '#samsung': 1,
#          '#servers': 1,
#          '#haken': 1,
#          '#insomnia': 1,
#          '#prog': 1,
#          '#microstudio': 1,
#          '#upload': 1})

# %%
hashtag_render = ""
for ht in list(hashtag_counter.keys()):
    hashtag_render += ht + " "
hashtag_render
# Out:
# '#friday #funtime #friends #cool #love #grupoasa #fila2015 #music #keyboards #teatro #teatrocomprimido #me #computer #rockprog #mac #apple #server #programming #scifi #car #lamborghini #interior #luxury #toronto #canada #candycrush #fail #hack #game #videogames #mustang #ford #homeserver #hp #proliant #caracas #venezuela #1tbofram #nvidia #custom #graphics #callortext #keyboard #korg #reason #cubase #musician #guitar #electricguitar #ibanez #working #gopro #system #cinema4d #animation #csap #roland #fantom #sbproject #camera #actioncamera #tbt #art #yamaha #ipad #rock #logicprox #finalcutpro #brothers #graduaci #musican #oasys #kronos #triton #88keys #61keys #inthestudio #piano #duet #tagsforlikes #macbook #boss #pedalboard #harmonist #solo #lifestyle #amazing #castle #vsti #moog #16gbram #windows #virtual #instruments #interface #midi #soundlibrary #customkeyboard #drums #tama #composing #recording #reason5 #lead #band #thebeatles #fourhands #letitbe #steinwain #impro #developer #galaxys7 #pro #team #melia #hotel #bussiness #titanx #pascal #computerscience #drawing #procreate #3d #helicopter #drone #motiontraking #aftereffects #wheater #fila2013 #winners #alterbridge #waterrising #cover #repost #macpro #myroland #workstation #profesional #homestudio #prestige #dell #vintage #mesabooguie #amps #noise #javascript #computergraphics #night #render #ucab #3danimation #intel #robot #programing #arduino #creative #raspberrypi #mixing #studio #troll #desktop #microsoft #unix #linux #nokia #aoc #htc #engineer #editing #photo #rails #asus #developerlife #backyard #timelapse #snow #progressive #mainstage #show #router #1gbps #internet #networking #cubase5 #pianissimo #synth #macintosh #effects #pool #dad #swag #familytime #ipads #screaminghead #keyboardist #jordanrudess #palajoda #dreamtheater #likesforlikes #iphoneonly #kurzweil #finalcut #fundapromusik #conservatory #iphone5s #musica #b #concert #style #colorful #hackacademy #developers #ios7 #sonitywolf #macbookpro #ai #styletranfer #daftpunk #funk #a33 #midicontroller #party #chill #family #bro #picoftheday #cntower #artificialintelligence #google #english #criminalminds #school #lol #wtfaces #ipadair #experimental #shirt #neon #britmusic #practicing #app #android #ios #electric #garageband #violin #allineed #supermario64 #mario #korggadget #korgmodule #promo6 #academiahack #keys #titan #computing #rendering #mylife #starbucks #code #lifeisgood #composer #mymusic #sibelius #yatch #logic #playing #sounds #animals #beauty #cloudcomputing #tensorflow #samplewiz #followme #celo #photoshop #nature #beautiful #instagood #electronic #follow #photooftheday #happy #selfie #like #smile #like4like #fun #summer #instadaily #fashion #igers #instalike #food #tflers #follow4follow #bestoftheday #6strings #black #ilac #theater #festivalfila #88 #hobbie #protools #mixer #axiomsolutions #goodtimes #cute #funny #friend #best #awesome #besties #crazy #picture #bestfriend #goodfriends #forever #haha #memories #bf #bff #gf #good #vocoder #blue #houses #neighbourhood #orchestra #2015 #virtualgrand #matrix #chelo #life #improvisaci #hacking #cold #city #broken #hate #tweegram #all #hackintosh #artwork #sibelius6 #birthday #bday #instabday #birthdaycake #cake #celebrate #candle #candles #young #old #years #instacake #happybirthday #instabirthday #born #niagarafalls #girl #hair #instamood #pianist #korgoasys #bass #store #disks #edit #imac #dualcam #videoediting #logicpro #followback #gibson #gift #lespaul #me25 #challenge #shot #metal #macosx #collection #desing #new #adobe #tarkus #master #realsports #house #polisynth #mesa #amp #gameofthrones #baldwin #cola #backstage #jackson #guitars #7strings #musical # #stage #underground #cam #tweak #lg #4k #coll #niagara #bossa #startupweekend #sound #drummers #ezdrummer #autodesk #maya #startup #fantomg8 #efects #wah #coffee #beta #python #xcode #marshall #vox #symphonic #elsistema #bossgt10 #musicproduction #sampletank #maudio #tesla #her #macosxtiger #core2duo #h ...

# %%
# Out:
# [('#music', 113),
#  ('#cool', 93),
#  ('#me', 60),
#  ('#keyboard', 46),
#  ('#apple', 36),
#  ('#korg', 35),
#  ('#art', 34),
#  ('#ibanez', 33),
#  ('#ipad', 31),
#  ('#piano', 29)]

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd

x = [tup[0] for tup in hashtag_counter.most_common(10)]
y = [tup[1] for tup in hashtag_counter.most_common(10)]
s = pd.Series(x, index=hashtag_counter.most_common(10))

s.plot.bar(figsize=(20,10))
plt.xlabel('Foo')
plt.ylabel('Bar')
plt.title("Hello Wolrd");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-00a3a4fb6fc1> in <module>()
#       7 s = pd.Series(hashtag_counter.most_common(10), index=hashtag_counter.most_common(10))
#       8
# ----> 9 s.plot.bar(figsize=(20,10))
#      10 plt.xlabel('Foo')
#      11 plt.ylabel('Bar')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, **kwds)
#    2536         axes : matplotlib.AxesSubplot or np.array of them
#    2537         """
# -> 2538         return self(kind='bar', **kwds)
#    2539
#    2540     def barh(self, **kwds):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1925                  yerr=yerr, xerr=xerr,
#    1926                  label=label, secondary_y=secondary_y,
# -> 1927                  **kwds)
#    1928
#    1929
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1727         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1728
# -> 1729     plot_obj.generate()
#    1730     plot_obj.draw()
#    1731     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     248     def generate(self):
#     249         self._args_adjust()
# --> 250         self._compute_plot_data()
#     251         self._setup_subplots()
#     252         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     363         if is_empty:
#     364             raise TypeError('Empty {0!r}: no numeric data to '
# --> 365                             'plot'.format(numeric_data.__class__.__name__))
#     366
#     367         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot
